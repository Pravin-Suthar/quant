# %%
import requests
import json
import mysql.connector
from datetime import datetime, timedelta
from tqdm import tqdm

# MySQL Configuration
DB_CONFIG = {
    'host': 'localhost',
    'user': 'root',
    'password': 'root',
    'database': 'hft_analytics'
}

# Instrument token for example (341249 is for RELIANCE in this case)
INSTRUMENT_TOKEN = "341249"
USER_ID = "XST433"  # Update if needed

# Function to create MySQL table
def create_table():
    conn = mysql.connector.connect(**DB_CONFIG)
    cursor = conn.cursor()
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS historical_data_1min_hdfc (
            timestamp DATETIME PRIMARY KEY,
            open FLOAT,
            high FLOAT,
            low FLOAT,
            close FLOAT,
            volume INT,
            oi INT
        )
    """)
    conn.commit()
    conn.close()
    print("✅ Table created (if not exists)")

# Function to fetch and store data for a specific date
def fetch_and_store(date_str):
    url = f"https://kite.zerodha.com/oms/instruments/historical/{INSTRUMENT_TOKEN}/minute?user_id={USER_ID}&oi=1&from={date_str}&to={date_str}"
    headers = {
        'User-Agent': 'Mozilla/5.0',
        'Authorization': 'enctoken HgCA1WIJ5p63kF2HQfCpELEIUs0YnLTlFnfHncKwKB0TqgYXKTq+KqZ/fIgJEF1g++MGHOizt3Nrx6/d0TUHnSjulAersUgj+cd+YSy6PJbv26ufV3qSUQ=='
    }
    
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"❌ Failed for {date_str} — Status: {response.status_code}")
        return

    data = response.json()
    if data.get("status") != "success":
        print(f"❌ API error for {date_str} — {data}")
        return
    
    candles = data["data"]["candles"]
    if not candles:
        return
    
    conn = mysql.connector.connect(**DB_CONFIG)
    cursor = conn.cursor()

    for candle in candles:
        timestamp, open_, high, low, close, volume, oi = candle
        timestamp = datetime.fromisoformat(timestamp.replace("+0530", "+05:30"))
        cursor.execute("""
            INSERT IGNORE INTO historical_data_1min_hdfc (timestamp, open, high, low, close, volume, oi)
            VALUES (%s, %s, %s, %s, %s, %s, %s)
        """, (timestamp, open_, high, low, close, volume, oi))

    conn.commit()
    conn.close()
    print(f"✅ Data stored for {date_str}")

# Run for all dates from Jan 1, 2020 to April 30, 2025
start_date = datetime(2024 ,8, 21)
end_date = datetime(2025, 4, 30)

# Create the table first
create_table()

# Loop through all dates
date = start_date
while date <= end_date:
    fetch_and_store(date.strftime("%Y-%m-%d"))
    date += timedelta(days=1)
# Out:
# ✅ Table created (if not exists)
# ✅ Data stored for 2024-08-21
# ✅ Data stored for 2024-08-22
# ✅ Data stored for 2024-08-23
# ✅ Data stored for 2024-08-26
# ✅ Data stored for 2024-08-27
# ✅ Data stored for 2024-08-28
# ✅ Data stored for 2024-08-29
# ✅ Data stored for 2024-08-30
# ✅ Data stored for 2024-09-02
# ✅ Data stored for 2024-09-03
# ✅ Data stored for 2024-09-04
# ✅ Data stored for 2024-09-05
# ✅ Data stored for 2024-09-06
# ✅ Data stored for 2024-09-09
# ✅ Data stored for 2024-09-10
# ✅ Data stored for 2024-09-11
# ✅ Data stored for 2024-09-12
# ✅ Data stored for 2024-09-13
# ✅ Data stored for 2024-09-16
# ✅ Data stored for 2024-09-17
# ✅ Data stored for 2024-09-18
# ✅ Data stored for 2024-09-19
# ✅ Data stored for 2024-09-20
# ✅ Data stored for 2024-09-23
# ✅ Data stored for 2024-09-24
# ✅ Data stored for 2024-09-25
# ✅ Data stored for 2024-09-26
# ✅ Data stored for 2024-09-27
# ✅ Data stored for 2024-09-30
# ✅ Data stored for 2024-10-01
# ✅ Data stored for 2024-10-03
# ✅ Data stored for 2024-10-04
# ✅ Data stored for 2024-10-07
# ✅ Data stored for 2024-10-08
# ✅ Data stored for 2024-10-09
# ✅ Data stored for 2024-10-10
# ✅ Data stored for 2024-10-11
# ✅ Data stored for 2024-10-14
# ✅ Data stored for 2024-10-15
# ✅ Data stored for 2024-10-16
# ✅ Data stored for 2024-10-17
# ✅ Data stored for 2024-10-18
# ✅ Data stored for 2024-10-21
# ✅ Data stored for 2024-10-22
# ✅ Data stored for 2024-10-23
# ✅ Data stored for 2024-10-24
# ✅ Data stored for 2024-10-25
# ✅ Data stored for 2024-10-28
# ✅ Data stored for 2024-10-29
# ✅ Data stored for 2024-10-30
# ✅ Data stored for 2024-10-31
# ✅ Data stored for 2024-11-01
# ✅ Data stored for 2024-11-04
# ✅ Data stored for 2024-11-05
# ✅ Data stored for 2024-11-06
# ✅ Data stored for 2024-11-07
# ✅ Data stored for 2024-11-08
# ✅ Data stored for 2024-11-11
# ✅ Data stored for 2024-11-12
# ✅ Data stored for 2024-11-13
# ✅ Data stored for 2024-11-14
# ✅ Data stored for 2024-11-18
# ✅ Data stored for 2024-11-19
# ✅ Data stored for 2024-11-21
# ✅ Data stored for 2024-11-22
# ✅ Data stored for 2024-11-25
# ✅ Data stored for 2024-11-26
# ✅ Data stored for 2024-11-27
# ✅ Data stored for 2024-11-28
# ✅ Data stored for 2024-11-29
# ✅ Data stored for 2024-12-02
# ✅ Data stored for 2024-12-03
# ✅ Data stored for 2024-12-04
# ✅ Data stored for 2024-12-05
# ✅ Data stored for 2024-12-06
# ✅ Data stored for 2024-12-09
# ✅ Data stored for 2024-12-10
# ✅ Data stored for 2024-12-11
# ✅ Data stored for 2024-12-12
# ✅ Data stored for 2024-12-13
# ✅ Data stored for 2024-12-16
# ✅ Data stored for 2024-12-17
# ✅ Data stored for 2024-12-18
# ✅ Data stored for 2024-12-19
# ✅ Data stored for 2024-12-20
# ✅ Data stored for 2024-12-23
# ✅ Data stored for 2024-12-24
# ✅ Data stored for 2024-12-26
# ✅ Data stored for 2024-12-27
# ✅ Data stored for 2024-12-30
# ✅ Data stored for 2024-12-31
# ✅ Data stored for 2025-01-01
# ✅ Data stored for 2025-01-02
# ✅ Data stored for 2025-01-03
# ✅ Data stored for 2025-01-06
# ✅ Data stored for 2025-01-07
# ✅ Data stored for 2025-01-08
# ✅ Data stored for 2025-01-09
# ✅ Data stored for 2025-01-10
# ✅ Data stored for 2025-01-13
# ✅ Data stored for 2025-01-14
# ✅ Data stored for 2025-01-15
# ✅ Data stored for 2025-01-16
# ✅ Data stored for 2025-01-17
# ✅ Data stored for 2025-01-20
# ✅ Data stored for 2025-01-21
# ✅ Data stored for 2025-01-22
# ✅ Data stored for 2025-01-23
# ✅ Data stored for 2025-01-24
# ✅ Data stored for 2025-01-27
# ✅ Data stored for 2025-01-28
# ✅ Data stored for 2025-01-29
# ✅ Data stored for 2025-01-30
# ✅ Data stored for 2025-01-31
# ✅ Data stored for 2025-02-01
# ✅ Data stored for 2025-02-03
# ✅ Data stored for 2025-02-04
# ✅ Data stored for 2025-02-05
# ✅ Data stored for 2025-02-06
# ✅ Data stored for 2025-02-07
# ✅ Data stored for 2025-02-10
# ✅ Data stored for 2025-02-11
# ✅ Data stored for 2025-02-12
# ✅ Data stored for 2025-02-13
# ✅ Data stored for 2025-02-14
# ✅ Data stored for 2025-02-17
# ✅ Data stored for 2025-02-18
# ✅ Data stored for 2025-02-19
# ✅ Data stored for 2025-02-20
# ✅ Data stored for 2025-02-21
# ✅ Data stored for 2025-02-24
# ✅ Data stored for 2025-02-25
# ✅ Data stored for 2025-02-27
# ✅ Data stored for 2025-02-28
# ✅ Data stored for 2025-03-03
# ✅ Data stored for 2025-03-04
# ✅ Data stored for 2025-03-05
# ✅ Data stored for 2025-03-06
# ✅ Data stored for 2025-03-07
# ✅ Data stored for 2025-03-10
# ✅ Data stored for 2025-03-11
# ✅ Data stored for 2025-03-12
# ✅ Data stored for 2025-03-13
# ✅ Data stored for 2025-03-17
# ✅ Data stored for 2025-03-18
# ✅ Data stored for 2025-03-19
# ✅ Data stored for 2025-03-20
# ✅ Data stored for 2025-03-21
# ✅ Data stored for 2025-03-24
# ✅ Data stored for 2025-03-25
# ✅ Data stored for 2025-03-26
# ✅ Data stored for 2025-03-27
# ✅ Data stored for 2025-03-28
# ✅ Data stored for 2025-04-01
# ✅ Data stored for 2025-04-02
# ✅ Data stored for 2025-04-03
# ✅ Data stored for 2025-04-04
# ✅ Data stored for 2025-04-07
# ✅ Data stored for 2025-04-08
# ✅ Data stored for 2025-04-09
# ✅ Data stored for 2025-04-11
# ✅ Data stored for 2025-04-15
# ✅ Data stored for 2025-04-16
# ✅ Data stored for 2025-04-17
# ✅ Data stored for 2025-04-21
# ✅ Data stored for 2025-04-22
# ✅ Data stored for 2025-04-23
# ✅ Data stored for 2025-04-24
# ✅ Data stored for 2025-04-25
# ✅ Data stored for 2025-04-28
# ✅ Data stored for 2025-04-29
# ✅ Data stored for 2025-04-30
